# %%
import pandas as pd
import glob
from glob import iglob
import csv
from collections import OrderedDict

# %%
df1 = pd.read_csv('DrDoS_NTP.csv')
df2 = pd.read_csv('DrDoS_LDAP.csv')
df3 = pd.read_csv('Syn.csv')
df4 = pd.read_csv('UDPLag.csv')
#data_frames = [df2, df3, df4]
df = df1.append([df2, df3, df4])
#df = df2.merge(df3.merge(df4, left_on=' Timestamp', right_on=' Timestamp'), left_on=' Timestamp', right_on=' Timestamp')
df = df.drop_duplicates()
#df_merged = df1.merge(df, left_on=' Timestamp', right_on=' Timestamp')
df
# Out:
#         Unnamed: 0                                Flow ID       Source IP  \
# 0                0     172.16.0.5-192.168.50.1-60675-80-6      172.16.0.5
# 1                7     172.16.0.5-192.168.50.1-60676-80-6      172.16.0.5
# 2            12858  192.168.50.7-65.55.163.78-50458-443-6    65.55.163.78
# 3            10191  192.168.50.7-65.55.163.78-50465-443-6    65.55.163.78
# 4              239         192.168.50.253-224.0.0.5-0-0-0  192.168.50.253
# ...            ...                                    ...             ...
# 370600      350624  172.16.0.5-192.168.50.1-60490-14102-6      172.16.0.5
# 370601      336856  172.16.0.5-192.168.50.1-60491-58360-6      172.16.0.5
# 370602      115128   172.16.0.5-192.168.50.1-60492-2905-6      172.16.0.5
# 370603       51370  172.16.0.5-192.168.50.1-60493-45714-6      172.16.0.5
# 370604      317173  172.16.0.5-192.168.50.1-60494-44935-6      172.16.0.5
#
#          Source Port  Destination IP   Destination Port   Protocol  \
# ...

# %%
df[" Label"].value_counts()
# Out:
# DrDoS_LDAP    2179930
# Syn           1582289
# DrDoS_NTP     1202642
# UDP-lag        366461
# BENIGN          20074
# WebDDoS           439
# Name:  Label, dtype: int64

# %%
df.to_csv('CICDDoS2019.csv')
